# %% [markdown]
# <a href="https://colab.research.google.com/github/COMPUTE-LU/AI4MedLife_LMs-Agents_2026/blob/main/colab_notebooks/Project_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project notebook - Template
# Use this notebook to help you develop your project in a stepwise manner. It is for yourself and will not have to be handed in as part of the examination.
#
# Copy the notebook to your own account and then add (with the + Code and + Text buttons above) and edit (by double-clicking on a cell) text and code cells as it suits you.
#
# Remember that AI development is iterative so don't hesitate to return to earlier steps and modify them as your knowledge about the task develops.

# %% [markdown]
# ## Your problem
#
# What is the research problem you want to solve? Write it down in one sentence below.
#
# Examples:
#
# *I want to develop a biomaterial for bone damage that does not prompt an immune response for patients who have lost pieces of their bone after traumatic injury.*
#
# *I want to understand which factors affect the population stability of Arctic cod.*
#
# **TASK**
#
# Write down what you want to solve!
#
# I want to...

# %% [markdown]
# ## Your task
# Pick a specific task related to your research problem that you want an AI system, or a hybrid AI-human system to solve. Be as specific as possible and update it throughout the project work if needed.
#
# Example:
#
# *First version: I want to build an AI tool that can predict the immunogenicity of biomaterials.
#
# Refined version: I want to build an AI tool that when given a biomaterial and a set of relevant properties, predicts the level of antibody productions against it.*
#
# **TASK**
#
# Write down your specific task!

# %% [markdown]
# #Your objective
# Define the specific measurable objective on which you will evaluate whether success is achieved. Refine as you go along.
#
# Example:
# *Objective: Develop a model that uses a biomaterial and properties, X, Y and Z as input and predicts the expected antibody titer as output.*
#
# *Succcess criteria: A working model that makes predictions with less than 10% Mean Absolute Percentage Error on the independent test set.*
#
# **TASK**
#
# Write down your objective and success criterion/criteria. Use them as starting point for designing your evaluation below.

# %% [markdown]
# **TASK**
#
# Use at least one, better two chatbots of your choice to refine your task and objective. If you don't know a suitable task or objective use them to brainstorm ideas first.
#
# **OPTIONAL TASK**
#
# Add a code cell below to use chatbots in this notebook. If you don't know how, use a chatbot to figure out how to do that.

# %% [markdown]
# #Your Data
#
# Explore and choose data for your AI to work with.
#
# **TASK**
#
# Use a chatbot to research data types, sources and specific datasets that you could use in your project.
#
# Ask the chatbot for the characteristics and limitations of the different data options.
#
# Evaluate whether the chatbot answers are fit for purpose/correct. Can the data really help you complete your task? If not, what would you need?
#
# **OPTIONAL TASK**
#
# Perform the research yourself, i.e. search for and read relevant literature or look through databases to find suitable data. You can also go back one step use what you discover as input for the chatbot to analyse.
#
# Compare your results to those of the chatbot.
#
# **TASK**
#
# Acquire the data you need for your project.
# If you cannot find suitable data, simulate it. For examination 1, you could also continue working only on a conceptual level if you cannot get data easily even by simulation. For the extended project (6 ECTS) you will need some data to actually work on, so if you cannot obtain or simulate it, you will need to find a new task.
#
# **OPTIONAL TASK**
#
# Compare the data suggestions and assessments of different chatbots.
# Use the chatbot to produce a structured table of datasets to use (with references).
#
# **TASK**
#
# Consider what you should look at during exploratory data analysis (EDA) for the type of data you have, both with regards to individual examples as well as with regards to the entire dataset(s). What flaws/errors do you expect in your dataset(s)?
#
# **TASK**
#
# Look at a few examples in your dataset(s) manually, e.g. open a few documents and glance through them. Then conduct a more extensive EDA on your data.
#
# **EXTENDED TASK (6 ECTS)**
#
# Address issues that you discover in your data in an appropriate manner.

# %% [markdown]
# # Your AI
# Decide the architecture of your AI system or model. Then try to develop it.
#
# **TASK**
#
# Use a chatbot to research architecture options and their advantages and disadvantages and to find out about existing AI that performs your task.
#
# **OPTIONAL TASK**
#
# Use more than one chatbot and then give them the solutions from the other chatbot(s) as alternatives. Let them compare to their respective solutions and build a consensus "best" architecture.
#
# **OPTIONAL TASK**
#
# Perform the research yourself, i.e. search for and read relevant literature or in model repositories. You can also go back one step use what you discover as input for the chatbot to analyse.
#
# Compare your results to those of the chatbot.
#
# **TASK**
#
# With the help of chatbots, 1. Test the existing AI (if anything exists). 2. Build your AI. Start simple and then try to improve it in a step-wise manner. See how far you can get by combining your own skills with those of the chatbots. Don't worry if you fail as it is not necessary to have a working system to pass the examinations. However, it is mandatory to reflect on the reasons you failed.
#
# **EXTENDED TASK (6 ECTS)**
#
# Develop a simple baseline first. Try out one or several approaches, and iteratively improve through more data, architectural changes, hyperparameter changes, etc.

# %% [markdown]
# #Your multimodality expansion
#
# Incorporate additional data types into your AI
#
# **TASK**
#
# Consider if another data modality could improve your AI and reflect on the advantages and disadvantages of expanding your system.
#
# **OPTIONAL TASK**
#
# If you think adding another data type could be beneficial, go back to your data steps and repeat them for this additional data type. Then update your AI to incorporate this new type of data.

# %% [markdown]
# #Your agentic AI workflow
# Make your AI more autonomous
#
# **TASK**
#
# Consider if your AI can be changed into an agentic AI workflow if it is not one already. If you already designed an agent, consider how it could be expanded into a more complex system.
#
# Evaluate the advantages and disadvantages of such a conversion.
#
# **TASK**
#
# Research different approaches to building such a workflow or expanding your AI agent and their respective strengths and weaknesses.
#
# **TASK**
#
# Consider what degree of autonomy your system should have and how you will establish human control where necessary.
#
# **OPTIONAL TASK**
#
# Develop the expanded AI system.

# %% [markdown]
# # Your evaluation
#
# Measure how well your AI completes its objective
#
# **TASK**
#
# Research different evaluation metrics and their limitations. Ensure they align with your research problem, task, objective and success criteria.
#
# Decide on a primary and secondary metrics that you want to use to evaluate your AI.
#
# **EXTENDED TASK (6 ECTS)**
#
# Establish your evaluation pipeline, comprising the evaluation itself and a standardized format for reporting it. Whether it is a simple table, a sheet of graphs or a fancy dashboard is up to you. Then use it to evaluate your AI and guide your iterative improvement.

# %% [markdown]
# # The bigger picture
#
# What matters besides the technology itself for your AI with regards to impact and deployment?
#
# **TASK**
#
# Consider the wider implications of your AI regarding privacy (explicit name any sensitive data), ethics (including bias), sustainability, bias, security, secondary use (not just for military but also whether it could be re-used for other research purposes), societal impact, as well as other releavant factors. Identify both positive and negative effects and affected groups/regions.
#
# **TASK**
#
# Consider what would be required to actually put your AI into use (e.g. infrastructure, staff training, monitoring, etc.)
#
# **TASK**
#
# Go back to you evaluation and add additional evaluation steps to assess the impact of your AI on the most critical issues you discovered in a systematic manner.
#
# **TASK**
#
# Go back to your AI. Consider how the explainability, governance, design and operation of your AI could be improved to better align it with the principles of responsible AI.
#
# **TASK**
#
# Consider what more would be needed to make your AI a reality.
#
# Decide what the next steps could be.
#
# **TASK**
#
# Decide whether you think your AI should be built and put into use.

# %% [markdown]
# # Your exam presentation
#
# Presentation length for examination 1: 15 min + 10 min questions
#
# Presentation length for examination 2: 20 min + 10 min questions
#
# The presentation has to include the following aspects:
#
# - Research problem with brief background, understandable to the course participants (max 1 slide)
# - Specific research task and objective (max 1 slide)
# - All Data used in the project. You have to use at least two data sources but neither needs to be real data. For examination 1, it is sufficient, if one of them is literature you read or analysed with a chatbot in relation to your project.
# - All AI used in the project, including any chatbots you have used. You have to use at least two types of AI. For examination 1, it is sufficient if one of them is a chatbot you used to support you in your project work and the second is the AI you planned/developed. For examination 2, it is sufficient if you trained two different models or explored two different architectures.
# - Results from the project. You do not need to have build a working AI to pass but you need to reflect on any failures and evaluate how much progress you have made in the holistic reflection section.
# - Holistic reflection on the project: 1. Limitations of the project, 2. Advantages and drawbacks of the overall project approach, data and employed AI, including a discussion of the failures an iterative improvements that were made, 3. Wider implications of the project with regards to privacy (explicitly name any sensitive data), ethics, sustainability, security, deployment and societal impact, etc. 4. Responsible AI approaches used in the project and possible improvements, 5. Suggestion for next steps
# - An extra slide(s) with references for ALL data, code and AI used in the project, in the same format as for a research article (not to be discussed in the presentation but simply included in the end). DOIs or other links to be included where available.
#
# **Note: The holistic reflection section should account for 50% of the slides of the presentation (excluding the reference slides).**
